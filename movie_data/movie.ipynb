# %%
import pandas as pd
movie_data=pd.read_csv('MOVIES.csv')

# %%
movie_data.head()
# Out:
#    adult           belongs_to_collection    budget original_language  \
# 0  False            Toy Story Collection  30000000                en
# 1  False                   not available  65000000                en
# 2  False       Grumpy Old Men Collection         0                en
# 3  False                   not available  16000000                en
# 4  False  Father of the Bride Collection         0                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...   17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...   11.712900   1995-12-22
# ...

# %%
movie_data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'original_language',
#        'original_title', 'overview', 'popularity', 'release_date', 'revenue',
#        'runtime', 'tagline', 'title', 'vote_average', 'vote_count',
#        'languages', 'day_of_week', 'month', 'season', 'year', 'has_homepage',
#        'genre', 'companies', 'countries'],
#       dtype='object')

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44985 entries, 0 to 44984
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  44985 non-null  bool
#  1   belongs_to_collection  44985 non-null  object
#  2   budget                 44985 non-null  int64
#  3   original_language      44985 non-null  object
#  4   original_title         44985 non-null  object
#  5   overview               44985 non-null  object
#  6   popularity             44985 non-null  float64
#  7   release_date           44985 non-null  object
#  8   revenue                44985 non-null  float64
#  9   runtime                44985 non-null  float64
#  10  tagline                44985 non-null  object
#  11  title                  44985 non-null  object
#  12  vote_average           44985 non-null  float64
#  13  vote_count             44985 non-null  float64
# ...

# %%
movie_data.isna().sum()
# Out:
# adult                    0
# belongs_to_collection    0
# budget                   0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# release_date             0
# revenue                  0
# runtime                  0
# tagline                  0
# title                    0
# vote_average             0
# vote_count               0
# languages                0
# day_of_week              0
# month                    0
# season                   0
# year                     0
# has_homepage             0
# genre                    0
# companies                0
# countries                0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
sns.lineplot(y='budget',x='year',data=movie_data[movie_data['year']>1874])
# Out:
# <Axes: xlabel='year', ylabel='budget'>

# %%
data=movie_data[movie_data['year']<1874]
data.shape
# Out:
# (78, 23)

# %%
sns.histplot(data=movie_data[movie_data['year']>1874],x='year')
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
sns.histplot(data=movie_data[movie_data['year']>1874],x='reva')
# Out:
# <Axes: xlabel='month', ylabel='Count'>

# %%
sns.histplot(data=movie_data[movie_data['year']>1874],x='season')
# Out:
# <Axes: xlabel='season', ylabel='Count'>

# %%
sns.barplot(data=movie_data[movie_data['year']>1874],x='season',y='revenue')
# Out:
# <Axes: xlabel='season', ylabel='revenue'>

# %%
sns.barplot(data=movie_data[movie_data['year']>1874],x='month',y='revenue')
# Out:
# <Axes: xlabel='month', ylabel='revenue'>
